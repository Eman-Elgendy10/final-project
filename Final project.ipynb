# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('supermarket_sales.csv')

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data.head (30)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 15  299-46-1805      B   Mandalay        Member  Female
# ...

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
data['Date'] = data['Date'].str.replace('/','-')

# %%
data['Date'].head(10)
# Out:
# 0     1-5-2019
# 1     3-8-2019
# 2     3-3-2019
# 3    1-27-2019
# 4     2-8-2019
# 5    3-25-2019
# 6    2-25-2019
# 7    2-24-2019
# 8    1-10-2019
# 9    2-20-2019
# Name: Date, dtype: object

# %%
data.rename(columns={'Total':'Total sales'},inplace=True)

# %%
data.rename(columns={'Payment':'Payment methode'},inplace=True)

# %%
data.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%  Total sales  \
# 0       Health and beauty       74.69         7  26.1415     548.9715
# 1  Electronic accessories       15.28         5   3.8200      80.2200
# 2      Home and lifestyle       46.33         7  16.2155     340.5255
# 3       Health and beauty       58.22         8  23.2880     489.0480
# ...

# %%
data['GOGS/Sales']=data['cogs']/data ['Total sales']

# %%
data['GOGS/Sales']
# Out:
# 0      0.952381
# 1      0.952381
# 2      0.952381
# 3      0.952381
# 4      0.952381
#          ...
# 995    0.952381
# 996    0.952381
# 997    0.952381
# 998    0.952381
# 999    0.952381
# Name: GOGS/Sales, Length: 1000, dtype: float64

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total sales                0
# Date                       0
# Time                       0
# Payment methode            0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# GOGS/Sales                 0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
Sales_by_products=data.groupby ('Product line')['Total sales'].sum()

# %%
Sales_by_products
# Out:
# Product line
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Food and beverages        56144.8440
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Sports and travel         55122.8265
# Name: Total sales, dtype: float64

# %%
Sales_by_products.sort_values(ascending=False).plot(kind='bar', color='g')
plt.xticks(rotation =75)
plt.grid( axis ='y', color ='g' , alpha= 0.35, linestyle =':')
plt.title('Sales by products', fontsize= 15)
plt.xlabel('products')
plt.ylabel('Sales')
sns.despine()

# %%
Sales_by_gender=data.groupby ('Gender')['Total sales'].sum()

# %%
Sales_by_gender
# Out:
# Gender
# Female    167882.925
# Male      155083.824
# Name: Total sales, dtype: float64

# %%
Sales_per_month =data.groupby ('Date')['Total sales'].sum()

# %%
plt.pie(Sales_by_gender,startangle=90, labels =Sales_by_gender.index, colors =['#2D3255','#f6B17A'], autopct='%1i%%')
plt.legend (labels =Sales_by_gender.values, loc ='upper left')
plt.title('Sales by gender', fontsize= 15)
# Out:
# Text(0.5, 1.0, 'Sales by gender')

# %%
Top_products_by_quantity =data.groupby ('Product line')['Quantity'].sum()

# %%
Top_products_by_quantity
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %%
Top_products_by_quantity.sort_values(ascending=False).plot(kind='bar', color='purple')
plt.xticks(rotation =75)
plt.title('products by quantity', fontsize= 15)
plt.xlabel('products')
plt.ylabel('Quantity')
sns.despine()

# %%
Top_rated_products =data.groupby ('Product line')['Rating'].mean()

# %%
Top_rated_products
# Out:
# Product line
# Electronic accessories    6.924706
# Fashion accessories       7.029213
# Food and beverages        7.113218
# Health and beauty         7.003289
# Home and lifestyle        6.837500
# Sports and travel         6.916265
# Name: Rating, dtype: float64

# %%
Top_rated_products.sort_values(ascending=True).plot(kind='barh', color='darkred')
plt.xticks(rotation =90)
plt.title('Top rated products', fontsize= 15)
plt.xlabel('rating')
plt.ylabel('products')
sns.despine()

# %%
data['Date']=pd.to_datetime(data['Date'])
Sales_per_month = data.groupby('Date')['Total sales'].sum().reset_index()
plt.figure(figsize=(10,5))
plt.title('Total sales by date', fontsize= 15)
plt.fill_between(Sales_per_month['Date'],Sales_per_month['Total sales'],color='skyblue', alpha=0.4)
plt.plot(Sales_per_month['Date'], Sales_per_month['Total sales'], color='blue', alpha=0.6)

# %%
sales_by_city =data.groupby ('City')['Total sales'].sum()

# %%
sales_by_city
# Out:
# City
# Mandalay     106197.6720
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Name: Total sales, dtype: float64

# %%
plt.figure (figsize=(8,6))
plt .pie(sales_by_city,labels= sales_by_city.index,startangle=90,autopct='%1i%%')
plt.title ('sales by city')
# Out:
# Text(0.5, 1.0, 'sales by city')

# %%
perffered_payment_method =data.groupby ('Payment methode')['Invoice ID'].count()

# %%
perffered_payment_method
# Out:
# Payment methode
# Cash           344
# Credit card    311
# Ewallet        345
# Name: Invoice ID, dtype: int64

# %%
perffered_payment_method.sort_values(ascending=False).plot(kind='bar', color='orange')
plt.xticks(rotation =45)
plt.title('perffered payment method', fontsize= 15)
plt.xlabel('Payment methode')
plt.ylabel('sales')
sns.despine()

# %%
sales_by_Branch =data.groupby ('Branch')['Total sales'].sum()

# %%
sales_by_Branch
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total sales, dtype: float64

# %%
sales_by_Branch.sort_values(ascending=False).plot(kind='bar', color='darkblue')
plt.title('sales by Branch', fontsize= 15)
plt.xlabel('Branch')
plt.ylabel('sales')
sns.despine()

# %%
data.to_excel("cleaned data.xlsx",index=False)
